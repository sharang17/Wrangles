# %%
import pandas as pd

# %%
crime=pd.read_csv("Data/crime.csv")
crime_n=pd.read_csv("Data/crime.csv")

# %%
crime.head()
# Out:
#                              CSA2010  \
# 0      Allendale/Irvington/S. Hilton
# 1    Beechfield/Ten Hills/West Hills
# 2                      Belair-Edison
# 3  Brooklyn/Curtis Bay/Hawkins Point
# 4                             Canton
#
#    Part 1 Crime Rate per 1,000 Residents (2010)  \
# 0                                          40.6
# 1                                          33.6
# 2                                          50.3
# 3                                          81.7
# 4                                          61.0
#
#    Part 1 Crime Rate per 1,000 Residents (2011)  \
# 0                                          46.2
# 1                                          36.1
# 2                                          57.1
# 3                                          79.1
# 4                                          64.8
#
#    Part 1 Crime Rate per 1,000 Residents (2012)  \
# 0                                          45.4
# ...

# %%
crime_neighbourhood=pd.DataFrame()
