# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
import seaborn as sns 
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

# %%
art=pd.read_csv("art_rankings.csv")

# %%
art.head(n=5)
# Out:
#    Unnamed: 0                   Community  Art Score  Crime  Population 19-24  \
# 0          54         Downtown/Seton Hill  38.312207  243.3              20.6
# 1          42   Inner Harbor/Federal Hill  13.312217   79.3              13.3
# 2          49                     Midtown   8.788034   84.2              22.6
# 3          52  Washington Village/Pigtown   6.869644  139.4              11.3
# 4          53    Harbor East/Little Italy   4.745294  159.4               9.8
#
#    Population 25-64     Income
# 0              67.6  44,819.40
# 1              66.6  88,854.21
# 2              58.7  38,866.80
# 3              59.5  48,175.04
# 4              59.6  36,578.63

# %%
art=art.drop("Unnamed: 0",1)

# %%
sns.jointplot(x="Art Score",y="Crime",kind="reg",data=art)

# %%
top_art=art.head(n=5)

# %%
top_art
# Out:
#                     Community  Art Score  Crime  Population 19-24  \
# 0         Downtown/Seton Hill  38.312207  243.3              20.6
# 1   Inner Harbor/Federal Hill  13.312217   79.3              13.3
# 2                     Midtown   8.788034   84.2              22.6
# 3  Washington Village/Pigtown   6.869644  139.4              11.3
# 4    Harbor East/Little Italy   4.745294  159.4               9.8
#
#    Population 25-64     Income
# 0              67.6  44,819.40
# 1              66.6  88,854.21
# 2              58.7  38,866.80
# 3              59.5  48,175.04
# 4              59.6  36,578.63

# %%
f, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6), sharex=True)
ax1.set(ylim=(0,100))
ax1.set_ylabel("Population between ages 16-24")
x = np.array(list(top_art["Community"]))
y1 =np.array(list(top_art["Population 19-24"]))
g=sns.barplot(x, y1, palette="RdBu_r", ax=ax1)


y2=np.array(list(top_art["Population 25-64"]))
sns.barplot(x, y2, palette="RdBu_r", ax=ax2)
ax2.set(ylim=(0,100))
ax2.set_ylabel("Population between ages 25-64")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text xticklabel objects>)
